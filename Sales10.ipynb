# %%
# !pip install pdfplumber

# %%
import pdfplumber
import pandas as pd
import re

def extract_data_from_pdf_revised(pdf_path):
    df = pd.DataFrame(columns=['Doc_Date', 'Time', 'No.', 'All_Bill', 'Product_Code', 'Barcode', 'Quantity', 'Unit_Price'])

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            lines = text.split('\n')

            for line in lines:
                if line.strip() == '':
                    continue

                # Revised header pattern match
                match_header = re.match(r'(\d{2}/\d{2}/\d{4}) \((\d{2}:\d{2})\) ทูบคี าซ่า (\S+) ลูกค้าทั\(cid:\d{3}\)วไป (\d+.\d{2})', line)
                if match_header:
                    current_date, current_time, current_no, current_all_bill = match_header.groups()
                    continue

                # Product pattern match
                match_product = re.match(r'(\S+) / (\S+) (.+) (\d+\.\d{2}) (\d+\.\d{2})', line)
                if match_product:
                    product_code, barcode, product_name, quantity, unit_price = match_product.groups()
                    df = df.append({
                        'Doc_Date': current_date,
                        'Time': current_time,
                        'No.': current_no,
                        'All_Bill': current_all_bill,
                        'Product_Code': product_code,
                        'Barcode': barcode,
                        'Quantity': quantity,
                        'Unit_Price': unit_price
                    }, ignore_index=True)

    return df

# Path to the PDF file
pdf_path = 'Sales10.pdf'

# Extracting data from the PDF with the revised function
revised_result_df = extract_data_from_pdf_revised(pdf_path)
print(revised_result_df)
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# <ipython-input-50-ff4eca51ed48>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# <ipython-input-50-ff4eca51ed48>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# <ipython-input-50-ff4eca51ed48>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# <ipython-input-50-ff4eca51ed48>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# <ipython-input-50-ff4eca51ed48>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
revised_result_df
# Out:
#          Doc_Date   Time         No. All_Bill   Product_Code    Barcode  \
# 0      01/10/2023  00:00  0000127224   100.00         011055     011055
# 1      01/10/2023  00:00  0000127224   100.00         008003     008003
# 2      01/10/2023  00:00  0000127224   100.00  8852959004927  885295900
# 3      01/10/2023  00:00  0000127224   100.00  8850987128400  885098712
# 4      01/10/2023  00:00  0000127224   100.00         011093     011093
# ...           ...    ...         ...      ...            ...        ...
# 11514  31/10/2023  23:03  0000132450    36.00         011020     011020
# 11515  31/10/2023  23:03  0000132450    36.00  8850228005668  885022800
# 11516  31/10/2023  23:03  0000132450    36.00  8850100003409  885010000
# 11517  31/10/2023  23:12  0000132451     9.00         001001     001001
# 11518  31/10/2023  23:45  0000132452    15.00  8850987144998  885098714
#
#       Quantity Unit_Price
# 0         1.00      45.00
# 1         1.00       1.00
# ...

# %%
pip install xlsxwriter

# %%
import pandas as pd

# สร้าง ExcelWriter
with pd.ExcelWriter('Sales10.xlsx', engine='xlsxwriter') as writer:
    # สร้าง DataFrame ที่มีรูปแบบทศนิยมตามที่ต้องการ
    df_formatted = revised_result_df.copy()
    df_formatted[['All_Bill', 'Quantity', 'Unit_Price']] = df_formatted[['All_Bill', 'Quantity', 'Unit_Price']].round(2)

    # บันทึก DataFrame เป็นไฟล์ Excel
    df_formatted.to_excel(writer, index=False)

# %%
import pandas as pd

# อ่านข้อมูลจากไฟล์ Excel
file_path = 'Sales10.xlsx'
df = pd.read_excel(file_path)

# แสดงข้อมูล
print(df)
# Out:
#          Doc_Date   Time         No.  All_Bill   Product_Code    Barcode  \
# 0      01/10/2023  00:00  0000127224     100.0         011055     011055
# 1      01/10/2023  00:00  0000127224     100.0         008003     008003
# 2      01/10/2023  00:00  0000127224     100.0  8852959004927  885295900
# 3      01/10/2023  00:00  0000127224     100.0  8850987128400  885098712
# 4      01/10/2023  00:00  0000127224     100.0         011093     011093
# ...           ...    ...         ...       ...            ...        ...
# 11514  31/10/2023  23:03  0000132450      36.0         011020     011020
# 11515  31/10/2023  23:03  0000132450      36.0  8850228005668  885022800
# 11516  31/10/2023  23:03  0000132450      36.0  8850100003409  885010000
# 11517  31/10/2023  23:12  0000132451       9.0         001001     001001
# 11518  31/10/2023  23:45  0000132452      15.0  8850987144998  885098714
#
#        Quantity  Unit_Price
# 0           1.0       45.00
# 1           1.0        1.00
# ...
